# %% [markdown]
# # International Commerce
#
#
# ---
#
# ## Korea University CIS
#
# Frank Ch9
# Spring 2026
# Woo Jin Choi
#
#
# ---
#
# ## Learning Objectives
#
# LO1: Decompose short-run total costs of production into fixed costs and variable costs.
# LO2: Explain how the shape of the short-run total cost curve relates to the shape of the short-run production function.
# LO3: Explain the relationship between average variable cost, average total cost, and marginal cost.
# LO4: Explain why the optimal allocation of production across multiple facilities requires that marginal cost be the same in each.
# LO5: Explain how the relationship between the average and marginal product of a variable input is reflected in the relationship between the average and marginal cost curves.
# LO6: Characterize the optimal input combination for producing a given level of output in the long run and explain why an input's marginal product divided by its price must take the same value for every input.
# LO7: Explain how the degree of returns to scale in production is related to long-run production costs.
#
#
# ---
#
# ## Chapter Outline
#
# - Costs in the Short Run
# - Graphing the Total, Variable, and Fixed Cost Curves
# - Other Short-Run Costs
# - Allocating Production between Two Processes
# - The Relationship among MP, AP, MC, and AVC
# - Appendix 9A: Mathematical Extensions of the Theory of Costs
#
#
#
# ---
#
# ## Costs In the Short Run
#
# - Fixed cost (FC): cost that does not vary with the level of output in the short run (the cost of all fixed factors of production).
# - Variable cost (VC): cost that varies with the level of output in the short run (the cost of all variable factors of production).
# - Total cost (TC): all costs of production: the sum of variable cost and fixed cost.
#
#
#
# ---
#
# ## Costs In the Short Run
#
#
# ---
#
# ## TABLE 9.1
#
#
# ---
#
# ## The Short-Run Production Function for Zara's Cleaners
#
# The entries in each row of the right column tell the quantity of output produced by the quantity of variable input in the corresponding row of the left column. This production function initially exhibits increasing, then diminishing, returns to the variable input.
#
# | Quantity of labor ( person- $\mathrm{hr} / \mathrm{hr}$ ) | Quantity of output (bags/hr) |
# | :--- | :--- |
# | 0 | 0 |
# | 1 | 4 |
# | 2 | 14 |
# | 3 | 27 |
# | 4 | 43 |
# | 5 | 58 |
# | 6 | 72 |
# | 7 | 81 |
# | 8 | 86 |
#
#
# Figure 9.1: Output as a Function of One Variable Input
# ![](https://dl.dropboxusercontent.com/scl/fo/j4a8s5wy61xvs5oybeui7/ANMF1z3qkW3MJ9Abyb__4jU/4c7d4293-4178-41d9-afde-48db575a81f6-06.jpg?rlkey=ddga9u3w8434x8mjjp08hd8ry)
#
# Access the text alternative for slide images.
#
#
# ---
#
# ## Costs In the Short Run
#
# - Suppose Zara's Cleaner's using $L$ and $K$.
# - Price of Labor: $w=\$ 10 /$ hour
# - Price of Capital: $r=\$ 30$ / hour
# - At the moment (in the short run), $K_{0}=1$
#
#
#
# ---
#
# ## Costs In the Short Run
#
# ![](https://dl.dropboxusercontent.com/scl/fo/j4a8s5wy61xvs5oybeui7/ANMF1z3qkW3MJ9Abyb__4jU/4c7d4293-4178-41d9-afde-48db575a81f6-08.jpg?rlkey=ddga9u3w8434x8mjjp08hd8ry)
# ![](https://dl.dropboxusercontent.com/scl/fo/j4a8s5wy61xvs5oybeui7/ANMF1z3qkW3MJ9Abyb__4jU/4c7d4293-4178-41d9-afde-48db575a81f6-08.jpg?rlkey=ddga9u3w8434x8mjjp08hd8ry)
#
#
# ---
#
# ## Costs In the Short Run
#
# - Fixed Costs
#
# $$
# F C=r K_{0}=\$ 30 \times K_{0}=\$ 30
# $$
#
# - Variable Costs
#
# $$
# V C=w L=\$ 10 \times L
# $$
#
# - Total Costs
#
# $$
# T C=F C+V C=r K_{0}+w L=\$ 30+\$ 10 \times L
# $$
#
#
# ---
#
# ## Costs In the Short Run
#
# The fixed cost of capital is $\$ 30 / \mathrm{hr}$, and the cost per unit of the variable factor $(L)$ is $\$ 10 / \mathrm{hr}$. Total cost is calculated as the sum of fixed cost and variable cost.
#
# TABLE 9.2
# Outputs and Costs
# | Q | FC | VC | TC |
# | :--- | :--- | :--- | :--- |
# | 0 | 30 | 0 | 30 |
# | 4 | 30 | 10 | 40 |
# | 14 | 30 | 20 | 50 |
# | 27 | 30 | 30 | 60 |
# | 43 | 30 | 40 | 70 |
# | 58 | 30 | 50 | 80 |
# | 72 | 30 | 60 | 90 |
# | 81 | 30 | 70 | 100 |
# | 86 | 30 | 80 | 110 |
#
#
#
# ---
#
# ## Graphing the Total, Variable, and Fixed Cost Curves
#
# - The shape of the variable cost curve is systematically related to the shape of the short-run production function.
# - The connection arises because the production function tells us how much labor we need to produce a given level of output, and this quantity of labor, when multiplied by the wage rate, gives us variable cost.
# - Because fixed costs do not vary with the level of output, their graph is simply a horizontal line.
#
#
#
# ---
#
# ## Figure 9.2: The Total, Variable, and Fixed Cost Curves
#
# ![](https://dl.dropboxusercontent.com/scl/fo/j4a8s5wy61xvs5oybeui7/ANMF1z3qkW3MJ9Abyb__4jU/4c7d4293-4178-41d9-afde-48db575a81f6-12.jpg?rlkey=ddga9u3w8434x8mjjp08hd8ry)
#
#
# ---
#
# ## FIGURE 9.2 <br> The Total, Variable, and Fixed Cost Curves
#
# These curves are for the production function for Zara's Cleaners, shown in
# Figure 9.1. The variable cost curve passes through the origin, which means that the variable cost of producing zero units of output is equal to zero. The TC curve, which is the sum of the FC and VC curves, is parallel to the VC curve and lies FC $=30$ units above it.
#
#
# ---
#
# ## Other Short-Run Costs
#
# - Average fixed cost (AFC): fixed cost divided by the quantity of output.
#
# $$
# A F C_{Q}=\frac{F C}{Q}=\frac{r K_{0}}{Q}
# $$
#
# - Average variable cost (AVC): variable cost divided by the quantity of output.
#
# $$
# A V C_{Q}=\frac{V C_{Q}}{Q}=\frac{w L}{Q}
# $$
#
#
# ---
#
# ## Other Short-Run Costs
#
# - Average total cost (ATC): total cost divided by the quantity of output.
#
# $$
# A T C_{Q}=A F C_{Q}+A V C_{Q}=\frac{r K_{0}}{Q}+\frac{w L}{Q}
# $$
#
# - Marginal cost (MC): change in total cost that results from a 1 -unit change in output.
#
# $$
# M C_{Q}=\frac{\Delta \mathrm{TC}_{Q}}{\Delta Q}=\frac{\Delta \mathrm{VC}_{Q}}{\Delta Q}
# $$
#
#
# ---
#
# ## Graphing the Short-Run Average and Marginal Cost Curves
#
# - Geometrically, average variable cost at any level of output $Q$ may be interpreted as the slope of a ray from the origin to the variable cost curve at $Q$.
# - Geometrically, marginal cost at any level of output may be interpreted as the slope of the total cost curve at that level of output.
# - Since the total cost and variable cost curves are parallel, marginal cost is also equal to the slope of the variable cost curve.
# - Marginal cost is the most important of the cost curves.
#
#
#
# ---
#
# ## Figure 9.5: The Marginal, Average Total, Average Variable, and Average Fixed Cost Curves
#
# ![](https://dl.dropboxusercontent.com/scl/fo/j4a8s5wy61xvs5oybeui7/ANMF1z3qkW3MJ9Abyb__4jU/4c7d4293-4178-41d9-afde-48db575a81f6-16.jpg?rlkey=ddga9u3w8434x8mjjp08hd8ry)
#
# Access the text alternative for slide images.
#
#
# ---
#
# ## Marginal and Average Costs
#
# - When MC is less than average cost (either ATC or AVC), the average cost curve must be decreasing with output.
# - When MC is greater than average cost, average cost must be increasing with output.
#
#
#
# ---
#
# ## Example 9.2 Determing Production Costs
#
#
# ---
#
# ## EXAMPLE 9.2 Determining Production Costs
#
# Construct a table showing average fixed cost, average variable cost, average total cost, and marginal cost using the information in Table 9.1 for Zara's Cleaners. Then graph these average costs.
#
# Outputs and Costs
# | Q | AFC | AVC | ATC | MC* |
# | :--- | :--- | :--- | :--- | :--- |
# | 0 | $\infty$ | - | $\infty$ |  |
# |  |  |  |  | 2.50 |
# | 4 | 7.50 | 2.50 | 10.00 |  |
# |  |  |  |  | 1.0 |
# | 14 | 2.14 | 1.43 | 3.57 |  |
# |  |  |  |  | 0.77 |
# | 27 | 1.11 | 1.11 | 2.22 |  |
# |  |  |  |  | 0.63 |
# | 43 | 0.70 | 0.93 | 1.63 |  |
# |  |  |  |  | 0.67 |
# | 58 | 0.52 | 0.86 | 1.38 |  |
# |  |  |  |  | 0.71 |
# | 72 | 0.42 | 0.83 | 1.25 |  |
# |  |  |  |  | 1.11 |
# | 81 | 0.37 | 0.86 | 1.23 |  |
# |  |  |  |  | 2.0 |
# | 86 | 0.35 | 0.93 | 1.28 |  |
#
#
# *The marginal cost entries are placed between the lines of the table to indicate that each entry represents the cost per bag of moving from the preceding output level to the next.
#
# Figure 9.6: Quantity vs. Average Costs
#
# ![](https://dl.dropboxusercontent.com/scl/fo/j4a8s5wy61xvs5oybeui7/ANMF1z3qkW3MJ9Abyb__4jU/4c7d4293-4178-41d9-afde-48db575a81f6-19.jpg?rlkey=ddga9u3w8434x8mjjp08hd8ry)
# FIGURE 9.6
# Quantity vs. Average Costs
# ATC is the sum of AVC and AFC. AFC is declining for all values of $Q$.
#
# Figure 9.3: The Production Function $\mathbf{Q} \boldsymbol{=} \mathbf{3} \boldsymbol{K} \boldsymbol{L}$, with $\boldsymbol{K} \boldsymbol{=} \mathbf{4}$
#
# - Let us do it with the functional form.
#
#
#
# ---
#
# ## Figure 9.3: The Production Function $Q=3 K L$, with $K=4$
#
# ![](https://dl.dropboxusercontent.com/scl/fo/j4a8s5wy61xvs5oybeui7/ANMF1z3qkW3MJ9Abyb__4jU/4c7d4293-4178-41d9-afde-48db575a81f6-21.jpg?rlkey=ddga9u3w8434x8mjjp08hd8ry)
# FIGURE 9.3
# The Production Function $Q=3 K L$, with $K=4$
#
# This short-run production function exhibits constant returns to $L$ over the entire range of $L$. There is neither a region of increasing returns nor a region of diminishing returns to $L$.
#
# Figure 9.4: The Total, Variable, and Fixed Cost Curves for the Production Function Q = 3KL
# ![](https://dl.dropboxusercontent.com/scl/fo/j4a8s5wy61xvs5oybeui7/ANMF1z3qkW3MJ9Abyb__4jU/4c7d4293-4178-41d9-afde-48db575a81f6-22.jpg?rlkey=ddga9u3w8434x8mjjp08hd8ry)
#
# - $\mathrm{TC}(\mathrm{Q})=\mathrm{FC}+\mathrm{VC}(\mathrm{Q})$
# = \$8 /hr + \$2Q/hr
#
# FC : (\$2/machine-hr ) (4 machine-hr/hr)
# VC : (\$24/person-hr) (Q/12 person-hr/hr)
#
#
# ---
#
# ## Self Test : the Production Function $\mathbf{Q} \boldsymbol{=} \mathbf{3} \boldsymbol{K} \boldsymbol{L}$
#
#
# ---
#
# ## SELF-TEST 9.1
#
# Same as Example 9.1 except the price of capital $r=\$ 4 /$ machine-hr.
#
# Answer
#
#
# ---
#
# ## Example 9.3 Graphing Cost Curves
#
# - Suppose output is given by the production function $Q= 3 K L$, where $K$ denotes capital and $L$ denotes labor. The price of capital is $\$ 2 /$ machine- $h r$, the price of labor is $\$ 24 /$ person-hr, and capital is fixed at 4 units in the short run.
# - Graph ATC, AVC, AFC, and MC curves.
#
#
#
# ---
#
# ## Example 9.3 Graphing Cost Curves
#
# $$
# \begin{gathered}
# T C_{Q}=8+2 Q \\
# M C_{Q}=\frac{\Delta T C_{Q}}{\Delta Q}=2 \\
# A V C_{Q}=\frac{2 Q}{Q}=2 \\
# A F C_{Q}=\frac{8}{Q} \\
# A T C_{Q}=2+\frac{8}{Q}
# \end{gathered}
# $$
#
#
# ---
#
# ## Figure 9.7: Cost Curves for a Specific Production Process
#
# ![](https://dl.dropboxusercontent.com/scl/fo/j4a8s5wy61xvs5oybeui7/ANMF1z3qkW3MJ9Abyb__4jU/4c7d4293-4178-41d9-afde-48db575a81f6-26.jpg?rlkey=ddga9u3w8434x8mjjp08hd8ry)
#
# Access the text alternative for slide images.
#
#
# ---
#
# ## Self Test 9.2
#
#
# ---
#
# ## SELF-TEST 9.2
#
# If FC takes the value 20 , what is the vertical distance between the ATC and AVC curves in Figure 9.5 when $Q=10$ ?
#
# Answer
#
#
# ---
#
# ## Allocating Production between Two Processes
#
# - Let $Q_{T}$ be the total amount to be produced, and let $Q_{1}$ and $Q_{2}$ be the amounts produced in the first and second processes, respectively. And suppose the marginal cost in either process at very low levels of output is lower than the marginal cost at $Q_{T}$ units of output in the other (which ensures that both processes will be used).
# - The values of $Q_{1}$ and $Q_{2}$ that solve this problem will then be the ones that result in equal marginal costs for the two processes.
#
#
#
# ---
#
# ## Example 9.4 Minimum-Cost Production
#
# - Suppose production processes A and B give rise to the following marginal and average total cost curves
#
# $$
# \begin{array}{ll}
# M C^{A}=12 Q^{A}, & A T C^{A}=\frac{16}{Q^{A}}+6 Q^{A} \\
# M C^{B}=4 Q^{B}, & A T C^{B}=\frac{240}{Q^{B}}+2 Q^{B} .
# \end{array}
# $$
#
# - Where the superscpirts denote processes A and B , respectively. What is the least costly way to produce a total of 32 units of output?
#
# Figure 9.8: The Minimum-Cost Production Allocation
# ![](https://dl.dropboxusercontent.com/scl/fo/j4a8s5wy61xvs5oybeui7/ANMF1z3qkW3MJ9Abyb__4jU/4c7d4293-4178-41d9-afde-48db575a81f6-30.jpg?rlkey=ddga9u3w8434x8mjjp08hd8ry)
#
#
# ---
#
# ## Costs in the Long Run
#
# - Isocost line: a set of input bundles, each of which costs the same amount.
# - To find the minimum cost point we begin with a specific isoquant, then superimpose a map of isocost lines, each corresponding to a different cost level.
# - The least-cost input bundle corresponds to the point of tangency between an isocost line and the specified isoquant.
#
#
#
# ---
#
# ## Costs in the Long Run
#
# - Suppose it uses only two inputs, capital $K$, and labor $L$, whose prices, measured in dollars per unit of input per day, are $r=2$ and $w=4$, respectively. What different combinations of inputs can this firm purchase for a total expenditure of $C=\$ 200 /$ day?
#
#
#
# ---
#
# ## Figure 9.10: The Isocost Line
#
# ![](https://dl.dropboxusercontent.com/scl/fo/j4a8s5wy61xvs5oybeui7/ANMF1z3qkW3MJ9Abyb__4jU/4c7d4293-4178-41d9-afde-48db575a81f6-33.jpg?rlkey=ddga9u3w8434x8mjjp08hd8ry)
# FIGURE 9.10
#
#
# ---
#
# ## The Isocost Line
#
# For given input prices ( $r=2$ and $w=4$ in the diagram), the isocost line is the locus of all possible input bundles that can be purchased for a given level of total expenditure $C(\$ 200$ in the diagram). The slope of the isocost line is the negative of the input price ratio, $-w / r$.
#
#
# ---
#
# ## Self Test 9.5
#
#
# ---
#
# ## SELF-TEST 9.5
#
# If $w=3$ and $r=6$, draw the isocost lines that correspond to total expenditure of \$90 and \$180 per unit of time.
#
# Answer
#
# ![](https://dl.dropboxusercontent.com/scl/fo/j4a8s5wy61xvs5oybeui7/ANMF1z3qkW3MJ9Abyb__4jU/4c7d4293-4178-41d9-afde-48db575a81f6-34.jpg?rlkey=ddga9u3w8434x8mjjp08hd8ry)
#
#
# ---
#
# ## Figure 9.11: The Maximum Output for a Given Expenditure
#
# ![](https://dl.dropboxusercontent.com/scl/fo/j4a8s5wy61xvs5oybeui7/ANMF1z3qkW3MJ9Abyb__4jU/4c7d4293-4178-41d9-afde-48db575a81f6-35.jpg?rlkey=ddga9u3w8434x8mjjp08hd8ry)
# FIGURE 9.11
# The Maximum Output for a Given Expenditure
#
# A firm that is trying to produce the largest possible output for an expenditure of $C$ will select the input combination at which the isocost line for $C$ is tangent to an isoquant.
#
#
# ---
#
# ## Figure 9.12: The Minimum Cost for a Given Level of Output
#
# ![](https://dl.dropboxusercontent.com/scl/fo/j4a8s5wy61xvs5oybeui7/ANMF1z3qkW3MJ9Abyb__4jU/4c7d4293-4178-41d9-afde-48db575a81f6-36.jpg?rlkey=ddga9u3w8434x8mjjp08hd8ry)
# FIGURE 9.12
# The Minimum Cost for a Given Level of Output
#
# A firm that is trying to produce a given level of output, $Q_{0}$, at the lowest possible cost will select the input combination at which an isocost line is tangent to the $Q_{0}$ isoquant.
#
#
# ---
#
# ## Choosing the Optimal Input Combination
#
# - Recall that the slope of the isoquant at any point is equal to $-\frac{M P_{L}}{M P_{K}}$.
# - Combining this with the result that minimum cost occurs at a point of tangency with the isocost line,
#
# $$
# \frac{M P_{L^{*}}}{M P_{K^{*}}}=\frac{w}{r}
# $$
#
# - where $K^{*}$ and $L^{*}$ denote the minimum-cost values of $K$ and $L$. Cross-multiplying, we have
#
# $$
# \frac{M P_{L^{*}}}{w}=\frac{M P_{K^{*}}}{r}
# $$
#
# Figure 9.13: Different Ways of Producing 1 Ton of Gravel
# ![](https://dl.dropboxusercontent.com/scl/fo/j4a8s5wy61xvs5oybeui7/ANMF1z3qkW3MJ9Abyb__4jU/4c7d4293-4178-41d9-afde-48db575a81f6-38.jpg?rlkey=ddga9u3w8434x8mjjp08hd8ry)
#
# [^0]Figure 9.14: The Effect of a Minimum Wage Law on Employment of Skilled Labor
# ![](https://dl.dropboxusercontent.com/scl/fo/j4a8s5wy61xvs5oybeui7/ANMF1z3qkW3MJ9Abyb__4jU/4c7d4293-4178-41d9-afde-48db575a81f6-39.jpg?rlkey=ddga9u3w8434x8mjjp08hd8ry)
#
# [^1]
#
# ---
#
# ## The Relationship between Optimal Input Choice and Long-Run Costs ${ }_{1}$
#
# - Output expansion path: the locus of tangencies (minimum-cost input combinations) traced out by an isocost line of given slope as it shifts outward into the isoquant map for a production process.
# - In the theory of firm behavior, the long-run expansion path is the analog to the income-consumption curve in the theory of the consumer.
#
# Figure 9.15: The Long-Run Expansion Path
# ![](https://dl.dropboxusercontent.com/scl/fo/j4a8s5wy61xvs5oybeui7/ANMF1z3qkW3MJ9Abyb__4jU/4c7d4293-4178-41d9-afde-48db575a81f6-41.jpg?rlkey=ddga9u3w8434x8mjjp08hd8ry)
#
# Figure 9.16: The Long-Run Total, Average, and Marginal Cost Curves
# ![](https://dl.dropboxusercontent.com/scl/fo/j4a8s5wy61xvs5oybeui7/ANMF1z3qkW3MJ9Abyb__4jU/4c7d4293-4178-41d9-afde-48db575a81f6-42.jpg?rlkey=ddga9u3w8434x8mjjp08hd8ry)
#
#
# ---
#
# ## Appendix 9A: Mathematical Extensions of the Theory of Costs
#
# - The LTC curve is generated by plotting the $Q$ value for a given isoquant against the corresponding total cost level for the isocost line tangent to that isoquant.
# - When the LAC curve is U-shaped, the tangencies between it and the associated ATC curves do not in general occur at the minimum points on the ATC curves.
# - The lone exception is the ATC curve that is tangent to the minimum point of the U-shaped LAC
#
#
#
# ---
#
# ## Figure 9A.1: The Short-Run and Long-Run Expansion Paths
#
# ![](https://dl.dropboxusercontent.com/scl/fo/j4a8s5wy61xvs5oybeui7/ANMF1z3qkW3MJ9Abyb__4jU/4c7d4293-4178-41d9-afde-48db575a81f6-44.jpg?rlkey=ddga9u3w8434x8mjjp08hd8ry)
#
# Figure 9A.2: The LTC and STC Curves Associated with the Isoquant Map in Figure A.9.1
# ![](https://dl.dropboxusercontent.com/scl/fo/j4a8s5wy61xvs5oybeui7/ANMF1z3qkW3MJ9Abyb__4jU/4c7d4293-4178-41d9-afde-48db575a81f6-45.jpg?rlkey=ddga9u3w8434x8mjjp08hd8ry)
#
# ![](https://dl.dropboxusercontent.com/scl/fo/j4a8s5wy61xvs5oybeui7/ANMF1z3qkW3MJ9Abyb__4jU/4c7d4293-4178-41d9-afde-48db575a81f6-45.jpg?rlkey=ddga9u3w8434x8mjjp08hd8ry)
#
# Figure 9A.3: The LAC, LMC, and Two ATC Curves Associated with the Cost Curves from Figure 9A. 2
# ![](https://dl.dropboxusercontent.com/scl/fo/j4a8s5wy61xvs5oybeui7/ANMF1z3qkW3MJ9Abyb__4jU/4c7d4293-4178-41d9-afde-48db575a81f6-46.jpg?rlkey=ddga9u3w8434x8mjjp08hd8ry)
#
# [^2]
#
# ---
#
# ## Figure 9A.4: The Family of Cost Curves Associated with a U-Shaped LAC
#
# ![](https://dl.dropboxusercontent.com/scl/fo/j4a8s5wy61xvs5oybeui7/ANMF1z3qkW3MJ9Abyb__4jU/4c7d4293-4178-41d9-afde-48db575a81f6-47.jpg?rlkey=ddga9u3w8434x8mjjp08hd8ry)
#
#
# ---
#
# ## The Calculus Approach to Cost Minimization
#
# - Using the Lagrangian technique from the Chapter 3 Appendix, we can show that the equality of MP/P ratios emerges as a necessary condition for the following costminimization problem:
# - $\min P_{K} K+P_{L} L$ subject to $F(K, L)=Q_{0}$. $K, L$
#
#
# [^0]:    Access the text alternative for slide images.
#
# [^1]:    Access the text alternative for slide images.
#
# [^2]:    Access the text alternative for slide images.

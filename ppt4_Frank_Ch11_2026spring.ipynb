# %% [markdown]
# # International Commerce
#
#
# ---
#
# ## Korea University CIS
#
# Frank Ch11
# Spring 2026
# Woo Jin Choi
#
#
# ---
#
# ## Learning Objectives $_{1}$
#
# LO1: Define a monopoly as the sole provider of a good or service with no close substitutes and as an entity that faces the entire downward-sloping demand curve of the market it serves.
# LO2: Describe five factors that often enable firms to become monopolists and explain why economies of scale and related network economies are the most important and enduring sources of monopoly.
# LO3: Explain why marginal revenue is typically less than the product price for a monopolist, but equal to price for a perfectly competitive firm.
# LO4: Explain why equilibrium in a monopoly market often fails to satisfy the conditions for economic efficiency.
#
#
# ---
#
# ## Learning Objectives $_{2}$
#
# LO5: Describe various techniques whereby monopolists are able to make price-sensitive buyers eligible for discounts while continuing to charge higher prices to buyers whose demands are less elastic.
#
# LO6: Explain how competitive forces affect the prices of unusually productive factors of production.
# LO7: Describe the various public policies that have been proposed for limiting efficiency losses attributable to monopoly.
#
#
# ---
#
# ## Chapter Outline
#
# - Defining Monopoly
# - Five Sources Of Monopoly
# - The Profit-Maximizing Monopolist
# - A Monopolist Has No Supply Curve
# - Price Discrimination
# - The Efficiency Loss from Monopoly
# - Public Policy toward Natural Monopoly
#
#
#
# ---
#
# ## Defining Monopoly
#
# - A monopoly is a market structure in which a single seller of a product with no close substitutes serves the entire market.
# - A monopoly has significant control over the price it charges.
# - The term is difficult to apply in practice.
# - The key feature that differentiates the monopoly from the competitive firm is the price elasticity of demand facing the firm.
#
#
#
# ---
#
# ## Five Sources Of Monopoly
#
# 1. Exclusive control over important inputs
# 2. Economies of scale
# 3. Patents
# 4. Network economies
# 5. Government licenses or franchises
#
# Figure 11.1: Natural Monopoly
# ![](https://dl.dropboxusercontent.com/scl/fo/j4a8s5wy61xvs5oybeui7/ANMF1z3qkW3MJ9Abyb__4jU/f0eb1c4a-b1f0-441e-a513-c0498c4e17d1-07.jpg?rlkey=ddga9u3w8434x8mjjp08hd8ry)
#
# FIGURE 11.1
# Natural Monopoly
#
# When the LAC curve is declining throughout, it is always cheaper for a single firm to serve the entire industry.
#
#
# ---
#
# ## The Profit-Maximizing Monopolist ${ }_{1}$
#
# - The monopolist's goal is to maximize economic profit.
# - In the short run, this means to choose the level of output for which the difference between total revenue and short-run total cost is greatest.
#
#
#
# ---
#
# ## The Monopolist's Total Revenue Curve
#
# - As price falls, total revenue for the monopolist does not rise linearly with output.
# - Instead, it reaches a maximum value at the quantity corresponding to the midpoint of the demand curve after which it again begins to fall.
# - Total revenue reaches its maximum value when the price elasticity of demand is unity.
#
#
#
# ---
#
# ## Figure 11.2: The Total Revenue Curve for a Perfect Competitor
#
#
# ---
#
# ## \$/unit of time <br> $$
# \mathrm{TR}=P^{*} Q
# $$ <br> $$
# \text { Slope }=P^{*}
# $$
#
#
# ---
#
# ## FIGURE 11.2
#
#
# ---
#
# ## The Total Revenue Curve for a Perfect Competitor
#
# Price for the perfect competitor remains at the shortrun equilibrium level $P *$ irrespective of the firm's output. Its total revenue is thus the product of $P *$ and the quantity it sells: $\mathrm{TR}=P^{*} Q$.
#
# Figure 11.3 Demand and Total Revenue
# ![](https://dl.dropboxusercontent.com/scl/fo/j4a8s5wy61xvs5oybeui7/ANMF1z3qkW3MJ9Abyb__4jU/f0eb1c4a-b1f0-441e-a513-c0498c4e17d1-11.jpg?rlkey=ddga9u3w8434x8mjjp08hd8ry)
#
# [^0]
#
# ---
#
# ## The Profit-Maximizing Monopolist ${ }_{1}$
#
# - Consider a monopolist with the downward-sloping demand curve
#
# $$
# P=80-\frac{1}{5} Q
# $$
#
# - At point A
# - It sells 100 units of output at a price of $\$ 60$
# - At point B
# - It sells 200 units of output at a price of $\$ 40$
# - At point C
# - It sells 300 units of output at a price of $\$ 20$
#
#
#
# ---
#
# ## Figure 11.4: Total Cost, Revenue, and Profit Curves for a Monopolist
#
# ![](https://dl.dropboxusercontent.com/scl/fo/j4a8s5wy61xvs5oybeui7/ANMF1z3qkW3MJ9Abyb__4jU/f0eb1c4a-b1f0-441e-a513-c0498c4e17d1-13.jpg?rlkey=ddga9u3w8434x8mjjp08hd8ry)
#
# Access the text alternative for slide images.
#
#
# ---
#
# ## The Profit-Maximizing Monopolist $_{1}$
#
# - The maximum profit occurs at
#
# $$
# Q^{*}=175
# $$
#
# - Profit at the point would be
#
# $$
# T R-T C=T R(Q)-T C(Q)
# $$
#
# - Profit Maximization!
#
# $$
# \begin{gathered}
# \frac{\Delta T R}{\Delta Q}-\frac{\Delta T C}{\Delta Q}=M R-M C=0 \\
# M R=M C
# \end{gathered}
# $$
#
#
# ---
#
# ## Marginal Revenue
#
# - Optimality condition for a monopolist: a monopolist maximizes profit by choosing the level of output where marginal revenue equals marginal cost.
# - Another useful way of thinking about marginal revenue is to view it as the gain in revenue from new sales minus the loss in revenue from selling the previous output level at the new, lower price.
#
#
#
# ---
#
# ## Figure 11.5: Changes in Total Revenue Resulting from a Price Cut
#
# ![](https://dl.dropboxusercontent.com/scl/fo/j4a8s5wy61xvs5oybeui7/ANMF1z3qkW3MJ9Abyb__4jU/f0eb1c4a-b1f0-441e-a513-c0498c4e17d1-16.jpg?rlkey=ddga9u3w8434x8mjjp08hd8ry)
#
#
# ---
#
# ## FIGURE 11.5
#
#
# ---
#
# ## Changes in Total Revenue Resulting from a Price Cut
#
# The area of rectangle $A(\$ 1,000 / \mathrm{wk})$ is the loss in revenue from selling the previous output level at a lower price. The area of rectangle $B(\$ 2,500 / \mathrm{wk})$ is the gain in revenue from selling the additional output at the new, lower price. Marginal revenue is the difference between these two areas $(\$ 2,500-\$ 1,000=\$ 1,500 / \mathrm{wk})$ divided by the change in output $(50$ units $/ \mathrm{wk})$. Here MR equals $\$ 30 /$ unit, which is less than the new price of $\$ 50 /$ unit.
#
#
# ---
#
# ## Figure 11.6: Marginal Revenue and Position on the Demand Curve
#
# ![](https://dl.dropboxusercontent.com/scl/fo/j4a8s5wy61xvs5oybeui7/ANMF1z3qkW3MJ9Abyb__4jU/f0eb1c4a-b1f0-441e-a513-c0498c4e17d1-17.jpg?rlkey=ddga9u3w8434x8mjjp08hd8ry)
# FIGURE 11.6
# Marginal Revenue and Position on the Demand Curve
#
# When $Q$ is to the left of the midpoint ( $M$ ) of a straight-line demand curve (for example, $Q=Q_{0}$ ), the gain from added sales (area $B$ ) outweighs the loss from a lower price for existing sales (area $A$ ). When $Q$ is to the right of the midpoint (for example, $Q=Q_{1}$ ), the gain from added sales (area $D$ ) is smaller than the loss from a lower price for existing sales (area C). At the midpoint of the demand curve, the gain and the loss are equal, which means marginal revenue is zero.
#
#
# ---
#
# ## Marginal Revenue and ELASTICITY
#
# - The less elastic demand is with respect to price, the more price will exceed marginal revenue.
# - For all elasticity values less than 1 in absolute value, marginal revenue will be negative.
# - For all elasticity values larger than 1 in absolute value marginal revenue will be positive.
# - In the limiting case of infinite price elasticity, marginal revenue and price are exactly the same.
#
#
#
# ---
#
# ## Marginal Revenue and ELASTICITY
#
# - Revenue increases
#
# $$
# \begin{gathered}
# R+\Delta R=(P+\Delta P) \times(Q+\Delta Q) \\
# =P Q+(\Delta P \times Q)+(P \times \Delta Q)-(\Delta P \times \Delta Q) \\
# =P Q+(\Delta P \times Q)+(P \times \Delta Q)=P Q+P Q\left(\frac{\Delta P}{P}\right)+P Q\left(\frac{\Delta Q}{Q}\right)
# \end{gathered}
# $$
#
# - Ignore ( $\Delta P \times \Delta Q$ ), as it is too small
# - $\frac{\Delta P}{P}: \%$ increase in $P$
# - $\frac{\Delta Q}{Q}: \%$ increase in $Q$
#
#
#
# ---
#
# ## Marginal Revenue and ELASTICITY (ctd)
#
# - \% increase in $R \approx \%$ increase in $P+\%$ increase in $P$
#
# $$
# \frac{\Delta R}{R} \approx \frac{\Delta P}{P}+\frac{\Delta Q}{Q}
# $$
#
# - Price elasticity
#
# $$
# \varepsilon=\left(\frac{\Delta Q}{Q}\right) /\left(\frac{\Delta P}{P}\right)
# $$
#
# Figure 11.8: A Specific Linear Demand Curve and the Corresponding Marginal Revenue Curve
# ![](https://dl.dropboxusercontent.com/scl/fo/j4a8s5wy61xvs5oybeui7/ANMF1z3qkW3MJ9Abyb__4jU/f0eb1c4a-b1f0-441e-a513-c0498c4e17d1-21.jpg?rlkey=ddga9u3w8434x8mjjp08hd8ry)
#
# Figure 11.9: The Profit-Maximizing Price and Quantity for a Monopolist
# ![](https://dl.dropboxusercontent.com/scl/fo/j4a8s5wy61xvs5oybeui7/ANMF1z3qkW3MJ9Abyb__4jU/f0eb1c4a-b1f0-441e-a513-c0498c4e17d1-22.jpg?rlkey=ddga9u3w8434x8mjjp08hd8ry)
#
# [^1]
#
# ---
#
# ## Example 11.2 Profit-Maximizing Monopolist ${ }_{2}$
#
# - A monopolist faces a demand curve of
#
# $$
# P=100-2 Q
# $$
#
# - And a short run total cost curve of
#
# $$
# T C=640+20 Q
# $$
#
# - What is the profit maximizing price? How much will the monopolist sell, and how much economic profit will it earn at that price?
#
# Figure 11.10: The Profit-Maximizing Price and Quantity for Specific Cost and Demand Functions
#
# ![](https://dl.dropboxusercontent.com/scl/fo/j4a8s5wy61xvs5oybeui7/ANMF1z3qkW3MJ9Abyb__4jU/f0eb1c4a-b1f0-441e-a513-c0498c4e17d1-24.jpg?rlkey=ddga9u3w8434x8mjjp08hd8ry)
# FIGURE 11.10
#
# The Profit-Maximizing Price and Quantity for Specific Cost and Demand Functions
#
#
# ---
#
# ## A Monopolist Has No Supply Curve
#
# - The monopolist is not a price taker.
# - There is no unique correspondence between price and marginal revenue when the market demand curve shifts.
# - A given marginal revenue value for one demand curve can correspond to one price, while the same value of marginal revenue for a second demand curve corresponds to a different price.
# - Monopoly has a supply rule, which is to equate marginal revenue and marginal cost.
#
#
#
# ---
#
# ## Figure 11.3 Demand, Total Revenue, and ELASTICITY
#
# ![](https://dl.dropboxusercontent.com/scl/fo/j4a8s5wy61xvs5oybeui7/ANMF1z3qkW3MJ9Abyb__4jU/f0eb1c4a-b1f0-441e-a513-c0498c4e17d1-26.jpg?rlkey=ddga9u3w8434x8mjjp08hd8ry)
# FIGURE 11.3
# Demand, Total Revenue, and Elasticity
#
# For the monopolist to increase sales, it is necessary to cut price (top panel). Total revenue rises with quantity, reaches a maximum value, and then declines (middle panel). The quantity level for which the price elasticity of demand is unity corresponds to the midpoint of the demand curve, and at that value total revenue is maximized.
#
#
# ---
#
# ## Figure 11.7: The Demand Curve and Corresponding Marginal Revenue Curve
#
# ![](https://dl.dropboxusercontent.com/scl/fo/j4a8s5wy61xvs5oybeui7/ANMF1z3qkW3MJ9Abyb__4jU/f0eb1c4a-b1f0-441e-a513-c0498c4e17d1-27.jpg?rlkey=ddga9u3w8434x8mjjp08hd8ry)
# ![](https://dl.dropboxusercontent.com/scl/fo/j4a8s5wy61xvs5oybeui7/ANMF1z3qkW3MJ9Abyb__4jU/f0eb1c4a-b1f0-441e-a513-c0498c4e17d1-27.jpg?rlkey=ddga9u3w8434x8mjjp08hd8ry)
#
# Access the text alternative for slide images.
#
#
# ---
#
# ## Price Discrimination 1
#
# - Price discrimination is a practice where the monopolist charges different prices to different buyers.
# - Price discrimination is the term for charging different prices to buyers in completely separate markets (Thirddegree price discrimination)
#
#
#
# ---
#
# ## Figure 11.13: The Profit-Maximizing Monopolist Who Sells in Two Markets
#
# ![](https://dl.dropboxusercontent.com/scl/fo/j4a8s5wy61xvs5oybeui7/ANMF1z3qkW3MJ9Abyb__4jU/f0eb1c4a-b1f0-441e-a513-c0498c4e17d1-29.jpg?rlkey=ddga9u3w8434x8mjjp08hd8ry)
# FIGURE 11.13
# The Profit-Maximizing Monopolist Who Sells in Two Markets
#
# For a monopolist who sells in two markets, the profit-maximizing output level is where the $\Sigma \mathrm{MR}$ curve intersects the MC curve, here, $Q^{*}=10$. Marginal revenue in each market will be the same when $Q_{1}^{*}=4$ and $Q_{2}^{*}=6$ are sold in markets 1 and 2 , respectively.
#
#
# ---
#
# ## Figure 11.14: A Monopolist with a Perfectly Elastic Foreign Market
#
# - A monopolist has marginal costs $M C=Q$ and home market demand $P=30-Q$. The monopolist can also sell to a foreign market at a constant price $P_{F}=12$.
# - Find and graph the quantity produced, quantity sold in the home market, quantity sold in the foreign market, and price charged in the home market.
# - Explain why the monopolist's profits would fall if it were to produce the same quantity but sell more in the home market.
#
#
#
# ---
#
# ## Figure 11.14: A Monopolist with a Perfectly Elastic Foreign Market
#
# ![](https://dl.dropboxusercontent.com/scl/fo/j4a8s5wy61xvs5oybeui7/ANMF1z3qkW3MJ9Abyb__4jU/f0eb1c4a-b1f0-441e-a513-c0498c4e17d1-31.jpg?rlkey=ddga9u3w8434x8mjjp08hd8ry)
# FIGURE 11.14
# A Monopolist with a Perfectly Elastic Foreign Market
# The curve $\Sigma \mathrm{MR}$ overlays $\mathrm{MR}_{H}$ as long as $\mathrm{MR}_{H} \geq \mathrm{MR}_{F}$, and then overlays $\mathrm{MR}_{F}$. The profit-maximizing output level is where the $\Sigma \mathrm{MR}$ curve intersects the MC curve, here $Q^{*}=12$.
#
#
# ---
#
# ## Figure 11.14: A Monopolist with a Perfectly Elastic Foreign Market
#
# - The linear demand curve $P=30-Q$ has associated marginal revenue $M R=30-2 Q$. The profit maximizing level of output for a monopolist selling to segmented markets occurs whereh $\Sigma M R=M C$.
# - The horizontal sum of the maringal revenues across markets is the home marginal revenue function $M R_{H}$ up to home output where $M R_{F}=M R_{H}$, and then the foreign marginal revenue function $M R_{F}=12$ for any further units.
# - Total marginal revenue equals marginal cost at $M R_{F}=M C$, which solves for $Q=12$. Marginal cost for this level of output equals home marginal revenue at $30-2 Q_{H}=12$, so $Q_{H}=9$, with the remaining units sold abroad:
#
# $$
# Q_{F}=Q-Q_{H}=12-9=3
# $$
#
#
# ---
#
# ## Public Policy toward Natural Monopoly
#
# - State ownership and management
# - State regulation of private monopolies
# - Exclusive contracting for natural monopoly
# - Vigorous enforcement of antitrust laws
# - A laissez-faire policy toward natural monopoly
#
#
#
# ---
#
# ## State Ownership and Management
#
# - The government is not bound to earn at least a normal profit and can set a price equal to marginal cost and absorb economic losses out of general tax revenues.
# - Unattractive features of state ownership:
# - Weakens incentives for cost-conscious efficient management
# - X-inefficiency: a condition in which a firm fails to obtain maximum output from a given combination of inputs
#
#
#
# ---
#
# ## Remaining Alternatives for Natural Monopolies
#
# - Exclusive contracting for natural monopoly
# - Is often less expensive but can contain high fees for unforeseen changes in circumstances.
# - Vigorous enforcement of antitrust laws
# - Forbids mergers between competing companies with high combined market share of total industry output.
# - A laissez-faire policy toward natural monopoly
# - Most attractive in markets where the monopolist can employ the hurdle model of differential pricing.
#
#
# [^0]:    Access the text alternative for slide images.
#
# [^1]:    Access the text alternative for slide images.
